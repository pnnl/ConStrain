# %% [markdown]
# This demo showcases the usage of running a complete ConStrain verification process with a composed ConStrain workflow json file.
#
# Below is the runner code for running a multi-step verification process defined in `g36_demo_workflow.json`. This verification process runs 3 verification cases on a Modelica simulation dataset.
#
# Notes:
# - Users shall have all dependencies required by ConStrain installed to run this script:
#   - The project uses `poetry` to manage its dependencies, install it following the official installation instructions
#   - In the root folder run `poetry install`

# %%
import warnings
import sys, os

try:
    # works in scripts
    base_path = os.path.dirname(__file__)
except NameError:
    # fallback for notebooks
    base_path = os.getcwd()

# Change dir to align with workflow json file verification specification
os.chdir(os.path.join(base_path, "..", ".."))
# Insert the root directory at the beginning of sys.path to prioritize local constrain package
sys.path.insert(0, os.path.join(".."))

from constrain.api import Workflow

# %%
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=ResourceWarning)
workflow = Workflow(workflow="./demo/G36_demo/G36_demo_workflow.json")
workflow.run_workflow(verbose=True)
# Out:
# 2025-10-24 14:24:04 - root - INFO - No working_dir is specified
# 2025-10-24 14:24:04 - root - INFO - Start running workflow at 14:24:04
# 2025-10-24 14:24:04 - root - INFO - Importing packages specified in workflow -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Start running workflow with start state [load data] with maximum allowable number of states being [1000] -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 1: [load data] ...
# 2025-10-24 14:24:04 - root - INFO - Done. -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 2: [load verification cases] ...
# 2025-10-24 14:24:04 - root - INFO - Done. -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 3: [check original case length] ...
# 2025-10-24 14:24:04 - root - INFO - Done. -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 4: [validate cases] ...
# 2025-10-24 14:24:04 - root - INFO - Done. -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 5: [setup verification] ...
# 2025-10-24 14:24:04 - root - INFO - Done. -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 6: [configure verification runner] ...
# 2025-10-24 14:24:04 - root - INFO - path_to_custom_tolerance_file was not specified. The default tolerances will be used.
# 2025-10-24 14:24:04 - root - INFO - Done. -- [14:24:04]
# 2025-10-24 14:24:04 - root - INFO - Running state 7: [run verification] ...
# 2025-10-24 14:24:04 - root - INFO - =======
# 2025-10-24 14:24:04 - root - INFO - dev_settings
# 2025-10-24 14:24:04 - root - INFO - {'output_coil_heating': 'heating_output', 'output_coil_cooling': 'cooling_output', 'position_damper_air_return': 'ra_p', 'position_damper_air_return_max': 'max_ra_p', 'position_damper_air_outdoor': 'oa_p', 'position_damper_air_outdoor_max': 'max_oa_p'}
# 2025-10-24 14:24:04 - root - INFO - =======
# 2025-10-24 14:24:04 - root - INFO - parameters
# 2025-10-24 14:24:04 - root - INFO - {}
# 2025-10-24 14:24:04 - root - INFO - ===========
# Running case - G36ReturnAirDamperPositionForReliefDamperOrFan
# ===========
# 2025-10-24 14:24:05 - root - INFO - Verification results dict:
# 2025-10-24 14:24:05 - root - INFO - {'Sample #': 43201, 'Pass #': 24065, 'Fail #': 19136, 'Untested #': 0, 'Verification Passed?': False}
# 2025-10-24 14:24:12 - root - INFO - =======
# 2025-10-24 14:24:12 - root - INFO - dev_settings
# 2025-10-24 14:24:12 - root - INFO - {'output_coil_heating': 'heating_output', 'output_coil_cooling': 'cooling_output', 'position_damper_air_return': 'ra_p', 'position_damper_air_return_max': 'max_ra_p', 'position_damper_air_outdoor': 'oa_p', 'position_damper_air_outdoor_min': 'min_oa_p', 'position_damper_air_outdoor_max': 'max_oa_p', 'flag_economizer_limit': 'economizer_high_limit_reached'}
# 2025-10-24 14:24:12 - root - INFO - =======
# 2025-10-24 14:24:12 - root - INFO - parameters
# 2025-10-24 14:24:12 - root - INFO - {}
# 2025-10-24 14:24:12 - root - INFO - ===========
# Running case - G36OutdoorAirDamperPositionForReliefDamperOrFan
# ===========
# 2025-10-24 14:24:12 - root - INFO - Verification results dict:
# 2025-10-24 14:24:12 - root - INFO - {'Sample #': 43201, 'Pass #': 23282, 'Fail #': 19919, 'Untested #': 0, 'Verification Passed?': False}
# 2025-10-24 14:24:22 - root - INFO - =======
# 2025-10-24 14:24:22 - root - INFO - dev_settings
# 2025-10-24 14:24:22 - root - INFO - {'mode_operation': 'operation_mode', 'temperature_air_outdoor': 'oa_t', 'temperature_air_supply_max': 't_max', 'temperature_air_supply_setpoint': 'sa_t_sp_ac', 'temperature_air_outdoor_supply_min': 'oa_t_min', 'temperature_air_outdoor_supply_max': 'oa_t_max', 'temperature_air_supply_setpoint_cool_min': 'min_clg_sa_t_sp', 'temperature_air_supply_setpoint_cool_max': 'max_clg_sa_t_sp'}
# 2025-10-24 14:24:22 - root - INFO - =======
# 2025-10-24 14:24:22 - root - INFO - parameters
# 2025-10-24 14:24:22 - root - INFO - {}
# 2025-10-24 14:24:22 - root - INFO - ===========
# Running case - G36SupplyAirTemperatureSetpoint
# ===========
# 2025-10-24 14:24:22 - root - INFO - Verification results dict:
# 2025-10-24 14:24:22 - root - INFO - {'Sample #': 43201, 'Pass #': 23400, 'Fail #': 1007, 'Untested #': 18794, 'Verification Passed?': False}
# 2025-10-24 14:24:23 - root - WARNING - mode_operation cannot be plotted by itself, ignored in the plot.
# 2025-10-24 14:24:25 - root - WARNING - Verification Result cannot be plotted by itself, ignored in the plot.
# 2025-10-24 14:24:29 - root - WARNING - mode_operation cannot be plotted by itself, ignored in the plot.
# 2025-10-24 14:24:29 - root - WARNING - Verification Result cannot be plotted by itself, ignored in the plot.
# 2025-10-24 14:24:30 - root - INFO - Done. -- [14:24:30]
# 2025-10-24 14:24:30 - root - INFO - Running state 8: [check results] ...
# 2025-10-24 14:24:30 - root - INFO - Done. -- [14:24:30]
# 2025-10-24 14:24:30 - root - INFO - Running state 9: [check number of result files] ...
# 2025-10-24 14:24:30 - root - INFO - Done. -- [14:24:30]
# 2025-10-24 14:24:30 - root - INFO - Running state 10: [reporting_object_instantiation] ...
# 2025-10-24 14:24:30 - root - INFO - Done. -- [14:24:30]
# 2025-10-24 14:24:30 - root - INFO - Running state 11: [report_cases] ...
# 2025-10-24 14:24:30 - root - INFO - Done. -- [14:24:30]
# 2025-10-24 14:24:30 - root - INFO - Running state 12: [Success] ...
# 2025-10-24 14:24:30 - root - INFO - Done. -- [14:24:30]
# 2025-10-24 14:24:30 - root - INFO - Workflow done at 14:24:30, a total of 12 states were executed in 0:00:26.205879.
# Congratulations! the demo workflow is executed with expected results and no error!
